# %%
from calendar import month
import calendar
import pandas as pd

# %%
df = pd.read_csv('./data/11_march_2025.csv')
df
# Out:
#                            date    category  amount
# 0     2022-07-06 05:57:10 +0000  Restuarant    5.50
# 1     2022-07-06 05:57:27 +0000      Market    2.00
# 2     2022-07-06 05:58:12 +0000       Coffe   30.10
# 3     2022-07-06 05:58:25 +0000      Market   17.33
# 4     2022-07-06 05:59:00 +0000  Restuarant    5.50
# ...                         ...         ...     ...
# 4592  2025-03-09 18:16:33 +0000      Market    2.88
# 4593  2025-03-10 02:50:47 +0000   Transport    0.50
# 4594  2025-03-10 13:25:19 +0000   Transport    0.50
# 4595  2025-03-10 14:21:57 +0000      Market    7.50
# 4596  2025-03-11 02:42:35 +0000   Transport    0.50
#
# [4597 rows x 3 columns]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4597 entries, 0 to 4596
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      4597 non-null   datetime64[us, UTC]
#  1   category  4597 non-null   str
#  2   amount    4597 non-null   float64
# dtypes: datetime64[us, UTC](1), float64(1), str(1)
# memory usage: 107.9 KB

# %%
df.isnull().sum()
# Out:
# date        0
# category    0
# amount      0
# dtype: int64

# %%
df['year_month'] = df['date'].dt.strftime('%Y-%m')

# %%
df['month']
# Out:
# 0       2022-07
# 1       2022-07
# 2       2022-07
# 3       2022-07
# 4       2022-07
#          ...
# 4592    2025-03
# 4593    2025-03
# 4594    2025-03
# 4595    2025-03
# 4596    2025-03
# Name: month, Length: 4597, dtype: str

# %%
df['month'] = df['date'].dt.month

# %%
df['mes_nome'] = df['month'].apply(lambda x: calendar.month_name[x])

# %%
df['mes_nome']
# Out:
# 0        July
# 1        July
# 2        July
# 3        July
# 4        July
#         ...
# 4592    March
# 4593    March
# 4594    March
# 4595    March
# 4596    March
# Name: mes_nome, Length: 4597, dtype: str
